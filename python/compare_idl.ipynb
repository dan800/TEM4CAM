# %% [markdown]
# Compare python code to output from Rolando Garcia's IDL code

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
temfile = 'FWsc2000climo_f09_TEM_test05.diag.nc'
rgfile = '/glade/p/acom/acom-climate/rgarcia/concat_tem_diag_FWsc2000climo_0001-0001.nc'

ds = xr.open_dataset(temfile)
rg = xr.open_dataset(rgfile)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 60, nbnd: 2, lat: 192, ilev: 71)
# Coordinates:
#     zlon       float64 ...
#   * time       (time) object 0001-01-01 00:00:00 ... 0001-03-01 00:00:00
#   * lat        (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * ilev       (ilev) float64 4.5e-06 7.42e-06 1.223e-05 ... 967.5 985.1 1e+03
# Dimensions without coordinates: nbnd
# Data variables: (12/13)
#     date       (time) int32 ...
#     datesec    (time) int32 ...
#     time_bnds  (time, nbnd) object ...
#     uzm        (time, ilev, lat) float32 ...
#     vzm        (time, ilev, lat) float32 ...
#     epfy       (time, ilev, lat) float64 ...
#     ...         ...
#     vtem       (time, ilev, lat) float32 ...
#     wtem       (time, ilev, lat) float64 ...
#     psitem     (time, ilev, lat) float64 ...
#     utendepfd  (time, ilev, lat) float64 ...
#     utendvtem  (time, ilev, lat) float64 ...
#     utendwtem  (time, ilev, lat) float64 ...
# Attributes:
# ...

# %%
rg
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 192, lev: 70, ilev: 71, time: 60)
# Coordinates:
#   * lat       (lat) float32 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lev       (lev) float32 5.96e-06 9.827e-06 1.62e-05 ... 957.5 976.3 992.6
#   * ilev      (ilev) float32 9.969e+36 9.969e+36 ... 9.969e+36 9.969e+36
#   * time      (time) datetime64[ns] 1950-01-01 1950-01-02 ... 1950-03-01
# Data variables: (12/19)
#     date      (time) int32 ...
#     datesec   (time) int32 ...
#     beg_year  float32 ...
#     P0        float32 ...
#     hyam      (lev) float32 ...
#     hybm      (lev) float32 ...
#     ...        ...
#     UBAR      (time, lev, lat) float32 ...
#     FY        (time, lev, lat) float32 ...
#     FZ        (time, lev, lat) float32 ...
#     DELF      (time, lev, lat) float32 ...
#     VT        (time, lev, lat) float32 ...
#     WT        (time, lev, lat) float32 ...
# Attributes:
#     source:   FWsc2000climo_f09_TEM_test05.cam.h6

# %%
ds.wtem.isel(time=-1).plot(y='ilev',yscale='log',
                          vmax = 0.01, ylim=[1e3,1e-3])
plt.show()

# %%
rg.WSTAR.isel(time=-1).plot(y='lev',yscale='log',
                          vmax = 0.01, ylim=[1e3,1e-3])
plt.show()
# Out:
# /glade/work/marsh/miniconda3/envs/default/lib/python3.9/site-packages/matplotlib/colors.py:576: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N

# %%
ds.vtem.isel(time=-1).plot(y='ilev',yscale='log',
                          vmax=5,ylim=[1e3,1e-3])
plt.show()

# %%
rg.VSTAR.isel(time=-1).plot(y='lev',yscale='log',
                          vmax=5,ylim=[1e3,1e-3])
plt.show()
